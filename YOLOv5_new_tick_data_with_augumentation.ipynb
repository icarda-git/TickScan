# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augumentation
# Out:
# [Errno 2] No such file or directory: '/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augumentation'
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# %cd /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augumentation
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.9.0+cu111 (Tesla T4)

# %%
cd /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5
# Out:
# /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 150 --data custom_data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=custom_data.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, patience=100, freeze=0, save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 2021-10-12 torch 1.9.0+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# ...

# %%
# !python detect.py --weights /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/weights/best.pt --img 640 --conf 0.25 --source /content/drive/MyDrive/test_yolo/
# Out:
# detect: weights=['/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/weights/best.pt'], source=/content/drive/MyDrive/test_yolo/, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-0-g956be8e torch 1.9.0+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# Fusing layers...
# Model Summary: 213 layers, 7039792 parameters, 0 gradients
# image 1/4 /content/drive/MyDrive/test_yolo/DF_val.jpg: 384x640 1 dromedarii_female, Done. (0.023s)
# image 2/4 /content/drive/MyDrive/test_yolo/DM_val.jpg: 384x640 1 dromedarii_male, Done. (0.012s)
# image 3/4 /content/drive/MyDrive/test_yolo/SF_val.jpg: 384x640 1 scupense_female, Done. (0.012s)
# ...

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
# %tensorboard --logdir /content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train

# %% [markdown]
# ## Predictions

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/detect/exp2/DF_val.jpg")
cv2_imshow(img)

# %% [markdown]
# Trainin Batches

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/train_batch0.jpg")
cv2_imshow(img)

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/train_batch1.jpg")
cv2_imshow(img)

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/train_batch2.jpg")
cv2_imshow(img)

# %% [markdown]
# ##original validation batch

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/val_batch0_labels.jpg")
cv2_imshow(img)

# %% [markdown]
# ##Predicted validation batch

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/val_batch0_pred.jpg")
cv2_imshow(img)

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/val_batch1_labels.jpg")
cv2_imshow(img)

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/val_batch1_pred.jpg")
cv2_imshow(img)

# %% [markdown]
# ##F1 curve

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/F1_curve.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2250x1500 at 0x7F69D8149B10>

# %% [markdown]
# ##PR_curve

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/PR_curve.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2250x1500 at 0x7F69D8159BD0>

# %% [markdown]
# ##P_curve

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/P_curve.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2250x1500 at 0x7F69D8159210>

# %% [markdown]
# ##R_curve

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/R_curve.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2250x1500 at 0x7F69D81457D0>

# %% [markdown]
# ##confusion matrix

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/confusion_matrix.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=3000x2250 at 0x7F69D8149050>

# %% [markdown]
# ##Loss with train and validation

# %%
img = cv2.imread("/content/drive/MyDrive/tick_YOLOv5_model_new_tick_data_augmentation/yolov5/runs/train/exp3/results.png")
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=2400x1200 at 0x7F69D814EBD0>
