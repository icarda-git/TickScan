# %% [markdown]
# # Setup (Run Once)

# %%
# !git clone https://github.com/icarda-git/TickScan
# Out:
# Cloning into 'TickScan'...
# remote: Enumerating objects: 390, done.
# remote: Counting objects: 100% (390/390), done.
# remote: Compressing objects: 100% (269/269), done.
# remote: Total 390 (delta 111), reused 347 (delta 94), pack-reused 0
# Receiving objects: 100% (390/390), 101.00 MiB | 22.84 MiB/s, done.
# Resolving deltas: 100% (111/111), done.
# Checking out files: 100% (2269/2269), done.

# %%
cd TickScan
# Out:
# /content/TickScan/TickScan/TickScan

# %%
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
import numpy as np
import torch
print(torch.cuda.is_available())
    
# !git clone https://github.com/ultralytics/yolov5  
# %pip install -qr requirements.txt  # install dependencies

import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# !pip install pyyaml==5.3.1
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla P100-PCIE-16GB)
# ...

# %%
# !cp -r './test_image.jpg' './yolov5'

# %%
# !cp -r './best.pt' './yolov5'

# %% [markdown]
# # Run inference

# %%
pwd
# Out:
# '/content/TickScan/TickScan/TickScan'

# %%
# !python detect.py --model 'yolov5' --model_location ./best.pt --input_location ./test_image.jpg --conf 0.5
# Out:
# detect: weights=['./best.pt'], source=./test_image.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.0-273-g4de8b24 torch 1.10.0+cu111 CUDA:0 (Tesla P100-PCIE-16GB, 16281MiB)

# %%
import cv2
import  matplotlib.pyplot as plt

img = cv2.imread('./yolov5/runs/detect/exp/test_image.jpg')
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.axis('off')
plt.imshow(img)
